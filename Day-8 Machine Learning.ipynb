# %% [markdown]
# ### Step-1 Understand Multi-Linear Regression
# ### Step-2 Splite dataset in in two format " Train & Test"
# ### Step-3 Prediction By Multi-Linear Regression Algorithm
# ### Step-4 Prediction By Linear Regression Formula

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings 
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv(r"C:\Users\jites\OneDrive\Desktop\archive\Salary_Data.csv")
df.head(3)
# Out:
#    YearsExperience   Age  Salary
# 0              1.1  21.0   39343
# 1              1.3  21.5   46205
# 2              1.5  21.7   37731

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Age                0
# Salary             0
# dtype: int64

# %%
sns.pairplot(data=df)
plt.show()

# %% [markdown]
# # Step-2 Splite dataset in in two format " Train & Test"

# %%
df.shape
# Out:
# (30, 3)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train ,x_test ,y_train ,y_test =train_test_split(x,y,train_size=.50,random_state=90)

# %%
x_train.shape ,x_test.shape
# Out:
# ((15, 2), (15, 2))

# %% [markdown]
# # Step-3 Prediction By Multi-Linear Regression Algorithm

# %%
x=df.iloc[:,:-1]
y=df["Salary"]

# %%
from sklearn.linear_model import LinearRegression

# %%
l_reg =LinearRegression()
l_reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
l_reg.score(x_test,y_test)*100
# Out:
# 94.82936351003177

# %%
l_reg.predict([[1.5,21.7]])                     # [[YearsExperience,Age]]
# Out:
# array([41831.94703081])

# %% [markdown]
# # Step-4 Prediction By Linear Regression Formula

# %%
l_reg.coef_
# Out:
# array([4971.15795414, 2558.24471061])

# %%
l_reg.intercept_
# Out:
# np.float64(-21138.7001207304)

# %%
# y_pred = m1*x1 + m2*x2 + C
# y_pred = 4971.15795414 * YearsExperience + 2558.24471061 * Age + (-21138.7001207304)

# %%
y_pred = 4971.15795414 * 1.5 + 2558.24471061 * 21.7+ (-21138.7001207304)
y_pred
# Out:
# 41831.9470307166
